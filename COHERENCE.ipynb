# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\xx\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\xx\anaconda3\lib\site-packages (from gensim) (1.22.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\xx\anaconda3\lib\site-packages (from gensim) (1.7.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\xx\anaconda3\lib\site-packages (from gensim) (5.2.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: FuzzyTM>=0.4.0 in c:\users\xx\anaconda3\lib\site-packages (from gensim) (2.0.5)
# Requirement already satisfied: pandas in c:\users\xx\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (1.4.4)
# Requirement already satisfied: pyfume in c:\users\xx\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\xx\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\xx\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3.post1)
# Requirement already satisfied: simpful in c:\users\xx\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.10.0)
# Requirement already satisfied: fst-pso in c:\users\xx\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\xx\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: miniful in c:\users\xx\anaconda3\lib\site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: requests in c:\users\xx\anaconda3\lib\site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\xx\anaconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xx\anaconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\xx\anaconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xx\anaconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2024.2.2)

# %%
# Install the stopwords-nl package (if not already installed)
# !pip install stop-words
# Out:
# Requirement already satisfied: stop-words in c:\users\xx\anaconda3\lib\site-packages (2018.7.23)

# %%
import pandas as pd
from gensim.corpora.dictionary import Dictionary
from gensim.models.coherencemodel import CoherenceModel
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from stop_words import get_stop_words

# %%
# Load your preprocessed dataset
df = pd.read_csv('C:/Users/xx/dutch_newspapers_preprocessed_n.csv')

# %%
# Create a CountVectorizer for LDA
vectorizer = CountVectorizer(stop_words=get_stop_words('dutch'))
doc_term_matrix = vectorizer.fit_transform(df['processed_content'])

# %%
# Train LDA model
number_of_topics = 10  # Set the desired number of topics
lda = LatentDirichletAllocation(n_components=50, random_state=0)
lda.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=50, random_state=0)

# %%
from gensim.corpora.dictionary import Dictionary

# Get feature names
words = vectorizer.get_feature_names_out()

# Convert the document-term matrix to a list of (word, frequency) pairs for each document
corpus = [[(i, count) for i, count in enumerate(doc) if count > 0] for doc in doc_term_matrix.toarray()]

# Create a Gensim dictionary from the words
id2word = {i: word for i, word in enumerate(words)}
dictionary = Dictionary.from_corpus(corpus, id2word=id2word)

# %%
# Since texts in processed_content are already lemmatized and tokenized,
# convert string representations back into lists of words.
texts = [doc.split(',') for doc in df['processed_content']]  # Adjust splitting based on your actual delimiter

# %%
# Get the topics from the LDA model
topic_words = []
for topic_idx, topic in enumerate(lda.components_):
    top_features_ind = topic.argsort()[-10:]  # Adjust the number of words per topic as needed
    topic_words.append([words[i] for i in top_features_ind])

# %%
# Use Gensim's CoherenceModel to get the UMass coherence score
coherence_model = CoherenceModel(topics=topic_words, texts=texts, dictionary=dictionary, coherence='u_mass')
coherence_score = coherence_model.get_coherence()

print(f'The UMass coherence score for the LDA model is: {coherence_score:.4f}')
# Out:
# The UMass coherence score for the LDA model is: 0.0000

# %% [markdown]
# CHECK THE LISTS

# %%
texts = [doc.split(',') for doc in df['processed_content']]

# %%
for doc in texts[:5]:
    print(doc)
# Out:
# ["['maand'", " 'jaar'", " 'beginnen'", " 'baldadig'", " 'eindigen'", " 'feestelijk'", " 'krant'", " '25'", " 'jaar'", " 'tapelen'", " 'nieuws'", " 'grillig'", " 'afzet'", " 'wollendekens'", " 'aardgas'", " 'zn'", " 'centraal'", " 'verwarming'", " 'regering'", " 'willen'", " 'hoofdprijs'", " 'halfmiljoen'", " 'toto'", " 'staatsloterij'", " 'temeente'", " 'zeist'", " 'vlgen'", " 'nu'", " 'afgebran'", " 'textielfabriek'", " 'zó'", " 'fbouwd'", " 'noordoostpolder'", " 'verkeerszondaar'", " 'foor'", " 'zaterdagmiddag'", " 'verkeersles'", " 'bijwonen'", " 'trein'", " 'geel'", " 'reformeren'", " 'steken'", " 'buskes'", " 'cs'", " 'synode'", " 'zomaar'", " 'fre'", " 'maand'", " 'synode'", " 'verzoenend'", " 'gebaar'", " 'maken'", " 'betekenen'", " 'geldloper'", " 'amsterdam'", " 'nd'", " 'zwaargewond'", " 'gereformeerd'", " 'gemeente'", " 'protesteten'", " 'godslastering'", " 'via'", " 'televisie'", " 'kxhaofdcommissaris'", " 'blijven'", " 'ontslaan'", " 'negen'", " 'tien'", " 'niertransplantatie'", " 'blijken'", " 'lukken'", " 'henk'", " 'hoekstra'", " 'opvolgen'", " 'paul'", " 'groot'", " 'cpnvoorzitter'", " 'adelbertveremging'", " 'stellen'", " 'open'", " 'öse'", " 'medechristenen'", " 'twaalf'", " 'melden'", " 'krant'", " 'zeven'", " 'toor'", " 'gladheid'", " 'kwaad'", " 'dag'", " 'eelde'", " '21'", " 'graad'", " 'an'", " 'vlissingen'", " 'ptt'", " 'melden'", " 'winst'", " '141'", " 'miljoen'", " 'negen'", " 'verlies'", " 'honderd'", " 'miljoen'", " 'goed'", " 'dê'", " 'vers'", " 'jaarlijks'", " '110'", " 'miljoen'", " 'slijten'", " 'blijken'", " 'ter'", " 'mei'", " 'verlopen'", " 'amsterdam'", " 'rellerig'", " 'laat'", " 'nieuws'", " 'hoofdstad'", " 'carré'", " 'begrip'", " 'voorlopig'", " 'staan'", " 'koninklijk'", " 'paar'", " 'openen'", " 'frederiksplein'", " 'nieuw'", " 'nederlands'", " 'bank'", " 'twee'", " 'jongemanan'", " 'duwen'", " 'ün'", " 'recordafstand'", " '130'", " 'kilometer'", " 'heusden'", " 'as'", " 'gaan'", " 'zn'", " 'middeleeuws'", " 'vestingwerk'", " 'restaureren'", " 'mr'", " 'he'", " 'fan'", " 'vollenhoven'", " 'wonen'", " 'loo'", " 'gaan'", " 'heldemaatwj'", " 'werken'", " 'urk'", " 'ult'", " 'koningin'", " 'één'", " 'koninklijk'", " 'famen'", " 'knjgt'", " 'leer'", " 'binden'", " 'nieuw'", " 'psalmbenjming'", " 'dordrecht'", " 'krijgen'", " 'speciaal'", " 'baldadigheidspatrouille'", " 'klein'", " '1z'", " 'heemskerk'", " 'vondeling'", " 'leggen'", " 'aanmelden'", " 'dag'", " 'paar'", " 'honderd'", " 'adspirantpleegouders'", " 'nrine'", " '1'", " 'volgen'", " 'jaar'", " 'half'", " 'jaar'", " 'loonpauze'", " 'houden'", " 'ond'", " 'kast'", " 'week'", " 'laat'", " 'regering'", " 'feissinï'", " 'loonfront'", " 'toegeven'", " 'leven'", " 'wintasgevaarls'", " 'arnhems'", " 'leeuwenpark'", " 'toerist'", " 'autoraanpje'", " 'openen'", " 'leeuw'", " 'ernstig'", " 'gewond'", " 'enting'", " 'bu'", " 'dpe'", " 'hoogovens'", " 'eisen'", " 'twee'", " 'luchtmacht'", " '1'", " 'vpenburg'", " 'woensdrecht'", " 'ontruimen'", " 'tandarts'", " 'zeggen'", " 'fie'", " 'hopeloz'", " 'taak'", " 'drie4'", " 'viermdjoen'", " 'kiezen'", " 'laar'", " 'trekken'", " 'sx'", " 'kennis'", " 'maken'", " 'nieuw'", " 'soort'", " 'boterconcentraat'", " 'keuken'", " 'leer'", " 'eindhovens'", " 'vormgeving'", " 'stsen'", " 'inspraak'", " 'jaar'", " 'heel'", " 'onderwijsrumoer'", " 'eptemberper'", " 'september'", " 'üiien'", " 'onthulling'", " 'prinsjesdag'", " 'waarbij'", " 'ct'", " 'geluid'", " 'plan'", " 'wen'", " 'vaderclai'", " 'blauwogig'", " 'twee'", " 'prinses'", " 'beatrix'", " 'ielk'", " 'jaar'", " 'miljoennota'", " 'drie'", " 'prinsenkind'", " 'alrnefnjïeuw'", " 'één'", " 'praten'", " 'luwer'", " 'zomer'", " 'brengen'", " 'js'", " 'regen'", " 'zeggen'", " 'j3'", " 'nederlander'", " 'tandartsstudie'", " 'vu'", " 'beginnen'", " 'er'", " 'bedoeling'", " 'gctcel'", " 'plaatsen'", " 'tekort'", " 'nier'", " 'bedoeling'", " 'prime'", " 'chnstam'", " 'gaan'", " 'canada'", " 'nemen'", " 'blümff'", " 'geïnteresseerd'", " 'frvolgd'", " 'marwei ...
# ["['demonstreren'", " 'deugd'", " 'vraag'", " 'antivietnamdemonstranten'", " 'treure'", " 'voet'", " 'gooien'", " 'eigenlijk'", " 'komen'", " 'woedend'", " 'rus'", " 'hiel'", " 'bovenop'", " 'tsjechoslowakije'", " 'planten'", " 'lemand'", " 'antirussische'", " 'demonstratie'", " 'vragen'", " 'demonstreren'", " 'vuln'", " 'onrecht'", " 'wereld'", " 'barst'", " 'onrecht'", " 'keus'", " 'genoeg'", " 'terecht'", " 'ervan'", " 'verdenken'", " 'misdaad'", " 'rusland'", " 'tsjechoslowakije'", " 'bedrijven'", " 'erg'", " 'vinden'", " 'vraag'", " 'zoiets'", " 'zoiets'", " 'vragen'", " 'aandacht'", " 'onderwerp'", " 'willen'", " 'afleiden'", " 'demonstrant'", " 'orde'", " 'stellen'", " 'gaan'", " 'vietnamdemonstraties'", " 'gaan'", " 'nee'", " 'niemand'", " 'stellen'", " 'vraag'", " 'twee'", " 'verschil'", " 'onrecht'", " 'tsjechoslowakije'", " 'bedrijven'", " 'willen'", " 'betogen'", " 'demonstratie'", " 'nietcommunistisch'", " 'fascistisch'", " 'wandaad'", " 'verstoring'", " 'openbaar'", " 'orde'", " 'achten'", " 'beleven'", " 'week'", " 'waarin'", " 'eenkleinbeeld'", " 'igevoel'", " 'walging'", " 'overvallen'", " 'jegens'", " 'kerk'", " 'politiek'", " 'staat'", " 'krant'", " 'staan'", " 'vol'", " 'bericht'", " 'mens'", " 'woeden'", " 'maken'", " 'razend'", " 'onbekend'", " 'blijven'", " 'ambtenaar'", " 'ministerie'", " 'justitie'", " 'beslissen'", " 'vier'", " 'turks'", " 'vrouwe'", " 'terugmoest'", " 'turkije'", " 'stempel'", " 'halen'", " 'wég'", " 'moeizaam'", " 'elkaar'", " 'spaaren'", " 'geld'", " 'haast'", " 'voorstellen'", " 'leven'", " 'mens'", " 'satanisch'", " 'beslissing'", " 'nemen'", " 'braaf'", " 'huisvader'", " 'staan'", " 'buurt'", " 'bekend'", " 'vriendelijk'", " 'correct'", " 'man'", " 'voorschrift'", " 'redeneeren'", " 'vier'", " 'turks'", " 'vrouw'", " 'terug'", " 'weten'", " 'voelen'", " 'ambtenaar'", " 'heel'", " 'flink'", " 'beslissing'", " 'slapap'", " 'sentimenteel'", " 'overweging'", " 'laten'", " 'leiden'", " 'vallen'", " 'mee'", " 'oud'", " 'adam'", " 'ontdekken']"]
# ["['verslaggever'", " 'aagamsterdam'", " 'twee'", " 'vier'", " 'turks'", " 'vrouw'", " 'land'", " 'teruggezonden'", " 'verzuimden'", " 'nederlands'", " 'consulaat'", " 'istanboel'", " 'stempel'", " 'spoort'", " 'laten'", " 'aanbrengen'", " 'nederlands'", " 'regee'", " 'extrareiskos'", " 'maken'", " 'overkomst'", " 'ederland'", " 'vergoeden'", " 'krijgenpolak'", " 'hoeven'", " 'besluit'", " 'mogelijkheid'", " 'uitsluiten'", " 'jteeft'", " 'goed'", " 'trouw'", " 'j8'", " 'vrouw'", " 'aannemen'", " 'voorwaarde'", " 'voldoen'", " 'wil'", " 'jtoj'", " 'nederland'", " 'werkenen'", " 'voegen'", " 'zodat'", " 'mach'", " 'voorlopig'", " 'verblijf'", " 'sekregen'", " 'aangevraagd'", " 'vrouw'", " 'niét'", " 'vergoeden'", " 'wordenomdat'", " 'woordvoerder'", " 'ministerie'", " 'heel'", " 'goed'", " 'weten'", " 'voorwaarde'", " 'voldoen'", " 'proberen'", " 'vier'", " 'vrouw'", " 'één'", " 'kind'", " 'vorig'", " 'week'", " 'dinsdag'", " 'schiphol'", " 'arriveren'", " 'volgen'", " 'dag'", " 'last'", " 'ministerie'", " 'justitie'", " 'marechaussee'", " 'toestel'", " 'istanboel'", " 'zetten'", " 'stempel'", " 'paspoort'", " 'ontbreken'", " 'machtiging'", " 'voorlopig'", " 'verblijf'", " 'land'", " 'machtiging'", " '1'", " 'juli'", " '1968'", " 'nodig'", " 'buitenlands'", " 'gastarbeider'", " 'gezinlid'", " 'gezinshereniging'", " 'nederland'", " 'komen'", " 'twee'", " 'vrouw'", " 'ministerie'", " 'voorwaarde'", " 'voldeen'", " 'machtiging'", " 'krijgen'", " 'erom'", " 'vragen'", " 'machtiging'", " 'degelijk'", " 'gaan'", " 'vragen']"]
# ["['zaterdag'", " 'vertrek'", " 'nederland'", " 'nederlands'", " 'consulaat'", " 'istanboel'", " 'gaan'", " 'vragen'", " 'kloppen'", " 'stempel'", " 'voorlopig'", " 'verblijfsvergunning'", " 'verkrijgen'", " 'doordat'", " 'zaterdag'", " 'betrekken'", " 'functionaris'", " 'aanwezig'", " 'man'", " 'verzekeren'", " 'vrouw'", " 'orde'", " 'gevolg'", " 'vrouw'", " 'stempel'", " 'paspoort'", " 'reis'", " 'gaan'", " 'bedrijfleider'", " 'amersfoorts'", " 'onderneming'", " 'echtgenoat'", " 'turks'", " 'vrouw'", " 'werken'", " 'trachten'", " 'ministerie'", " 'justitie'", " 'krijgen'", " 'vrouw'", " 'paar'", " 'dag'", " 'and'", " 'blijven'", " 'intussen'", " 'per'", " 'exprespost'", " 'paspoort'", " 'consulaat'", " 'istanboel'", " 'zenden'", " 'stempel'", " 'laten'", " 'zetten'", " 'ministerie'", " 'staan'", " 'vrouw'", " 'stempel'", " 'gaan'", " 'halen'", " 'extra'", " 'reiskosten'", " 'ƒ'", " '700'", " 'kosten'", " 'voorwaarde'", " 'waaraan'", " 'gastarbeider'", " 'algemeen'", " 'voldoen'", " 'willen'", " 'gezinshereniging'", " 'nederland'", " 'vernemen'", " 'nader'", " 'drie'", " 'volgen'", " 'minstens'", " 'jaar'", " 'werken'", " 'minstens'", " 'jaar'", " 'werk'", " 'vooruitzicht'", " 'plaatselijk'", " 'overheid'", " 'passen'", " 'woonvergunning'", " 'drie'", " 'voorwaarde'", " 'vervullen'", " 'gezin'", " 'voorlopig'", " 'verblijfsvergunning'", " 'aanvragen'", " 'twee'", " 'vier'", " 'wasin'", " 'feit'", " 'voorwaarde'", " 'voldoen'", " 'twee'", " 'passen'", " 'woning'", " 'ministerie'", " 'justitie'", " 'aandacht'", " 'vestigen'", " 'gastarbeider'", " 'nederland'", " 'namelijk'", " 'politie'", " 'woonplaats'", " 'machtiging'", " 'voorlopig'", " 'verblijf'", " 'gezin'", " 'aanvragen'", " 'orde'", " 'bevinden'", " 'consul'", " 'bericht'", " 'vereisen'", " 'machtiging'", " 'verlenen'", " 'gezinlid'", " 'machtiging'", " 'afhalen'", " 'vertrekken'", " 'behoeven'", " 'twee'", " 'maal'", " 'consulaat'", " 'bezoeken']"]
# ["['twee'", " 'tweedekamerleden'", " 'drs'", " 'tilanus'", " 'chu'", " 'mevrouw'", " 'mr'", " 'singerdekker'", " 'pvda'", " 'regering'", " 'verzoeken'", " 'reiskost'", " 'vier'", " 'turks'", " 'vrouw'", " 'vergoeden'", " 'pvdakanierlid'", " 'vragen'", " 'minister'", " 'buitenlands'", " 'zaak'", " 'justitie'", " 'richten'", " 'informeren'", " 'gevolg'", " 'onjuist'", " 'voorlichting'", " 'nederlands'", " 'consulaat'", " 'istanboel'", " 'vrouw'", " 'vereisen'", " 'formaliteit'", " 'voldoen'", " 'verzoeken'", " 'maatregel'", " 'toekomst'", " 'onjuist'", " 'voorlichting'", " 'drs'", " 'tilanus'", " 'afvragen'", " 'minister'", " 'justitie'", " 'volgen'", " 'gang'", " 'zaak'", " 'menselijk'", " 'acht'", " 'vrouw'", " 'man'", " 'vier'", " 'jaar'", " 'nederland'", " 'werken'", " 'bunschoten'", " 'huisvesting'", " 'gezin'", " 'beschikbaar'", " 'toerist'", " 'enig'", " 'tijd'", " 'nederland'", " 'blijven']"]

# %%
# Verify the format of 'texts'
print(texts[:2])  # Print the first 2 documents to check their format
# Out:
# [["['maand'", " 'jaar'", " 'beginnen'", " 'baldadig'", " 'eindigen'", " 'feestelijk'", " 'krant'", " '25'", " 'jaar'", " 'tapelen'", " 'nieuws'", " 'grillig'", " 'afzet'", " 'wollendekens'", " 'aardgas'", " 'zn'", " 'centraal'", " 'verwarming'", " 'regering'", " 'willen'", " 'hoofdprijs'", " 'halfmiljoen'", " 'toto'", " 'staatsloterij'", " 'temeente'", " 'zeist'", " 'vlgen'", " 'nu'", " 'afgebran'", " 'textielfabriek'", " 'zó'", " 'fbouwd'", " 'noordoostpolder'", " 'verkeerszondaar'", " 'foor'", " 'zaterdagmiddag'", " 'verkeersles'", " 'bijwonen'", " 'trein'", " 'geel'", " 'reformeren'", " 'steken'", " 'buskes'", " 'cs'", " 'synode'", " 'zomaar'", " 'fre'", " 'maand'", " 'synode'", " 'verzoenend'", " 'gebaar'", " 'maken'", " 'betekenen'", " 'geldloper'", " 'amsterdam'", " 'nd'", " 'zwaargewond'", " 'gereformeerd'", " 'gemeente'", " 'protesteten'", " 'godslastering'", " 'via'", " 'televisie'", " 'kxhaofdcommissaris'", " 'blijven'", " 'ontslaan'", " 'negen'", " 'tien'", " 'niertransplantatie'", " 'blijken'", " 'lukken'", " 'henk'", " 'hoekstra'", " 'opvolgen'", " 'paul'", " 'groot'", " 'cpnvoorzitter'", " 'adelbertveremging'", " 'stellen'", " 'open'", " 'öse'", " 'medechristenen'", " 'twaalf'", " 'melden'", " 'krant'", " 'zeven'", " 'toor'", " 'gladheid'", " 'kwaad'", " 'dag'", " 'eelde'", " '21'", " 'graad'", " 'an'", " 'vlissingen'", " 'ptt'", " 'melden'", " 'winst'", " '141'", " 'miljoen'", " 'negen'", " 'verlies'", " 'honderd'", " 'miljoen'", " 'goed'", " 'dê'", " 'vers'", " 'jaarlijks'", " '110'", " 'miljoen'", " 'slijten'", " 'blijken'", " 'ter'", " 'mei'", " 'verlopen'", " 'amsterdam'", " 'rellerig'", " 'laat'", " 'nieuws'", " 'hoofdstad'", " 'carré'", " 'begrip'", " 'voorlopig'", " 'staan'", " 'koninklijk'", " 'paar'", " 'openen'", " 'frederiksplein'", " 'nieuw'", " 'nederlands'", " 'bank'", " 'twee'", " 'jongemanan'", " 'duwen'", " 'ün'", " 'recordafstand'", " '130'", " 'kilometer'", " 'heusden'", " 'as'", " 'gaan'", " 'zn'", " 'middeleeuws'", " 'vestingwerk'", " 'restaureren'", " 'mr'", " 'he'", " 'fan'", " 'vollenhoven'", " 'wonen'", " 'loo'", " 'gaan'", " 'heldemaatwj'", " 'werken'", " 'urk'", " 'ult'", " 'koningin'", " 'één'", " 'koninklijk'", " 'famen'", " 'knjgt'", " 'leer'", " 'binden'", " 'nieuw'", " 'psalmbenjming'", " 'dordrecht'", " 'krijgen'", " 'speciaal'", " 'baldadigheidspatrouille'", " 'klein'", " '1z'", " 'heemskerk'", " 'vondeling'", " 'leggen'", " 'aanmelden'", " 'dag'", " 'paar'", " 'honderd'", " 'adspirantpleegouders'", " 'nrine'", " '1'", " 'volgen'", " 'jaar'", " 'half'", " 'jaar'", " 'loonpauze'", " 'houden'", " 'ond'", " 'kast'", " 'week'", " 'laat'", " 'regering'", " 'feissinï'", " 'loonfront'", " 'toegeven'", " 'leven'", " 'wintasgevaarls'", " 'arnhems'", " 'leeuwenpark'", " 'toerist'", " 'autoraanpje'", " 'openen'", " 'leeuw'", " 'ernstig'", " 'gewond'", " 'enting'", " 'bu'", " 'dpe'", " 'hoogovens'", " 'eisen'", " 'twee'", " 'luchtmacht'", " '1'", " 'vpenburg'", " 'woensdrecht'", " 'ontruimen'", " 'tandarts'", " 'zeggen'", " 'fie'", " 'hopeloz'", " 'taak'", " 'drie4'", " 'viermdjoen'", " 'kiezen'", " 'laar'", " 'trekken'", " 'sx'", " 'kennis'", " 'maken'", " 'nieuw'", " 'soort'", " 'boterconcentraat'", " 'keuken'", " 'leer'", " 'eindhovens'", " 'vormgeving'", " 'stsen'", " 'inspraak'", " 'jaar'", " 'heel'", " 'onderwijsrumoer'", " 'eptemberper'", " 'september'", " 'üiien'", " 'onthulling'", " 'prinsjesdag'", " 'waarbij'", " 'ct'", " 'geluid'", " 'plan'", " 'wen'", " 'vaderclai'", " 'blauwogig'", " 'twee'", " 'prinses'", " 'beatrix'", " 'ielk'", " 'jaar'", " 'miljoennota'", " 'drie'", " 'prinsenkind'", " 'alrnefnjïeuw'", " 'één'", " 'praten'", " 'luwer'", " 'zomer'", " 'brengen'", " 'js'", " 'regen'", " 'zeggen'", " 'j3'", " 'nederlander'", " 'tandartsstudie'", " 'vu'", " 'beginnen'", " 'er'", " 'bedoeling'", " 'gctcel'", " 'plaatsen'", " 'tekort'", " 'nier'", " 'bedoeling'", " 'prime'", " 'chnstam'", " 'gaan'", " 'canada'", " 'nemen'", " 'blümff'", " 'geïnteresseerd'", " 'frvolgd'", " 'marwe ...
